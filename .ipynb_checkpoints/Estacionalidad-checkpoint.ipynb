# %% [markdown]
# # Estacionalidad

# %%
import numpy as np
import os
import pandas as pd
from functools import reduce
from itertools import product
from statsmodels.tsa.stattools import adfuller, kpss
import seaborn as sns
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf #Gráficos Autocorrelación
from statsmodels.tsa.arima_process import ArmaProcess #Simulación del proceso ARMA
from statsmodels.tsa.statespace.sarimax import SARIMAX #Ajuste del modelo
#Pruebas estadísticas
from statsmodels.stats.diagnostic import acorr_ljungbox, lilliefors, het_arch
#Descomposición
from statsmodels.tsa.seasonal import seasonal_decompose

def plotseasonal(descomp):
    fig, axes = plt.subplots(ncols=1, nrows=4, sharex=True, figsize=(12,5))
    descomp.observed.plot(ax=axes[0], legend=False)
    axes[0].set_ylabel('Observado')
    descomp.trend.plot(ax=axes[1], legend=False)
    axes[1].set_ylabel('Tendencia')
    descomp.seasonal.plot(ax=axes[2], legend=False)
    axes[2].set_ylabel('Estacionalidad')
    descomp.resid.plot(ax=axes[3], legend=False)
    axes[3].set_ylabel('Residuos')

# %% [markdown]
# ### Frecuencia
#
# * Número de observaciones por ciclo.
# * Para datos recolectados mensual, trimestral o semanalmente, el largo del ciclo es un año.
#
# |Frecuencia|$m$|
# |----|----|
# |Anual|1|
# |Trimestral (quarterly)|4|
# |Mensual| 12|
# |Semanal| 52|
#
# * Si los datos son diarios, $m=7$ representa un ciclo semanal, mientras que $m=365$ sería anual.

# %% [markdown]
# ## Diferenciación

# %%
carpeta_base = r"C:\Users\josea\Documents\GitHub\curso_series_tiempo\Datos"
#Leemos la bases
balance = pd.read_excel(os.path.join(carpeta_base, "balance_datos_completos.xlsx"))
balance.index = balance.fecha
td = balance[['tasa_desempleo']]

# %%
td.plot();

# %%
#Descomposición 
td_sd = seasonal_decompose(td, period = 12)
plotseasonal(td_sd)

# %%
#Prueba de estacionariedad
adfuller(td)[1] < 0.05
# Out:
# False

# %% [markdown]
# * $d = 1$

# %%
td_diff1 = td.diff().dropna()
td_sd = seasonal_decompose(td_diff1,period = 12)
plotseasonal(td_sd)

# %%
adfuller(td.diff().dropna())[1] < 0.05
# Out:
# True

# %%
plot_acf(td_diff1);

# %%
plot_pacf(td_diff1);

# %% [markdown]
# * $D = 12$

# %%
td_diff12 = (td - td.shift(12)).dropna()
td_sd = seasonal_decompose(td_diff12, period = 12)
plotseasonal(td_sd)

# %%
plot_acf(td_diff12);

# %%
plot_pacf(td_diff12);

# %% [markdown]
# * $d = 1$ y $D= 1$

# %%
td_diff1_12 = (td_diff1 - td_diff1.shift(12)).dropna()
td_sd = seasonal_decompose(td_diff1_12, period = 12)
plotseasonal(td_sd)

# %%
adfuller(td_diff1_12)[1] < 0.05
# Out:
# True

# %%
plot_acf(td_diff1_12);

# %%
plot_pacf(td_diff1_12);

# %% [markdown]
# ## Earnings per share

# %%
from pandas.tseries.offsets import DateOffset
eps = pd.read_excel(os.path.join(carpeta_base,"EPS.xlsx"), sheet_name = "P&G")
#trimestres = pd.to_datetime(eps['Fecha']) 
#eps.index = pd.DatetimeIndex(trimestres, freq = 'Q')
#eps.sort_index(inplace=True)
#period_index = pd.period_range(start=eps.index[0], end=eps.index[-1], freq='Q')
period_index = pd.to_datetime(eps['Fecha'])
eps=eps.set_index(period_index)
eps.drop('Fecha',axis=1,inplace=True)
eps.sort_index(inplace=True)

# %%
eps.plot();

# %%
print(np.argmin(eps))
print(np.argmax(eps))
# Out:
# 41
# 31

# %%
eps.iloc[41] = np.nan
eps.iloc[31] = np.nan

# %%
eps.iloc[41]
# Out:
# EPS   NaN
# Name: 2019-06-30 00:00:00, dtype: float64

# %%
eps.interpolate(inplace = True)

# %%
eps.plot();

# %%
ca_sd = seasonal_decompose(eps, period = 4)
plotseasonal(ca_sd)

# %%
#Prueba de estacionariedad
adfuller(eps)[1] < 0.05
# Out:
# False

# %%
plot_acf(eps);

# %%
plot_pacf(eps);

# %% [markdown]
# * **Tasa**

# %%
eps_tasa = np.log(eps).diff().dropna() #(eps/eps.shift(1)-1).dropna()
eps_tasa.plot();

# %%
#Prueba de estacionariedad
adfuller(eps_tasa)[1] < 0.05
# Out:
# True

# %%
ca_sd = seasonal_decompose(eps_tasa, period = 4)
plotseasonal(ca_sd)

# %%
plot_acf(eps_tasa);

# %%
plot_pacf(eps_tasa);

# %%
from sklearn.utils._testing import ignore_warnings
#from sklearn.exceptions import ValueWarning
# Función para seleccionar p, q, P, Q.
#@ignore_warnings(category=ConvergenceWarning)
def optimize_SARIMA(endog, order_list, d, D, s, maxiter = 50):
    results = []
    for order in order_list:
        #print(order)
        try: #Intentamos ajustar el modelo
            model = SARIMAX(endog, 
                            order=(order[0], d, order[1]),
                            seasonal_order=(order[2], D, order[3], s),
                            simple_differencing=False).fit(disp=False,maxiter = maxiter)
            #simple_differencing: indica si el modelo hace diff. antes de ajustar el modelo.
            #Es análogo a que la variable endog sea la diff. de la serie original.
            #Las predicciones serían con respecto a la serie diferenciada. 
        except:
            continue
        aic = model.aic #Se extrae el AIC
        results.append([order, aic])
    result_df = pd.DataFrame(results)
    result_df.columns = ['(p,q,P,Q)', 'AIC']
    #Se ordena con el menor AIC 
    result_df = result_df.sort_values(by='AIC',ascending=True).reset_index(drop=True)
    return result_df

# %%
train = eps_tasa[:-4]
test = eps_tasa.tail(4)
ps = range(0, 4, 1)
qs = range(0, 4, 1)
Ps = range(0, 3, 1)
Qs = range(0, 3, 1)
d = 0
D = 0
s = 4
ARIMA_order_list = list(product(ps, qs, Ps, Qs))
optimize_SARIMA(train, ARIMA_order_list, d, D, s, maxiter = 300)
# Out:
#         (p,q,P,Q)        AIC
# 0    (0, 1, 1, 1)  28.877686
# 1    (0, 2, 1, 1)  30.563410
# 2    (0, 1, 2, 1)  30.567829
# 3    (0, 1, 1, 2)  30.598594
# 4    (1, 1, 1, 1)  30.647647
# ..            ...        ...
# 139  (0, 0, 2, 0)  53.505797
# 140  (0, 0, 0, 2)  53.845269
# 141  (0, 0, 0, 0)  54.243494
# 142  (0, 0, 1, 0)  55.496423
# 143  (0, 0, 0, 1)  55.752998
#
# [144 rows x 2 columns]

# %%
modelo0 = SARIMAX(train, order=(0,0,1),
                seasonal_order=(1,0,1,4),
                simple_differencing=False).fit(disp=False,maxiter = 300)
modelo0.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                               EPS   No. Observations:                   56
# Model:             SARIMAX(0, 0, 1)x(1, 0, 1, 4)   Log Likelihood                 -10.439
# Date:                           Sun, 04 Aug 2024   AIC                             28.878
# Time:                                   12:20:57   BIC                             36.979
# Sample:                               06-30-2009   HQIC                            32.019
#                                     - 03-31-2023
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7776      0.155     -5.026      0.000      -1.081      -0.474
# ar.S.L4        0.9990      0.212      4.709      0.000       0.583       1.415
# ...

# %%
modelo0.plot_diagnostics();

# %% [markdown]
# # Automatización

# %%
from pmdarima.arima import auto_arima

# %%
modelo1 = auto_arima(y = train, m=4)

# %%
modelo2 = auto_arima(y = train, m=4, with_intercept = False)

# %%
modelo3 = auto_arima(y = train, m = 4, stepwise = False)

# %%
modelo4 = auto_arima(y = train, m=4, with_intercept = False, stepwise = False)

# %%
modelo1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                                 y   No. Observations:                   56
# Model:             SARIMAX(0, 0, 1)x(1, 0, 1, 4)   Log Likelihood                 -10.377
# Date:                           Sun, 04 Aug 2024   AIC                             30.754
# Time:                                   11:24:14   BIC                             40.881
# Sample:                               06-30-2009   HQIC                            34.680
#                                     - 03-31-2023
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   3.239e-05      0.003      0.012      0.990      -0.005       0.005
# ma.L1         -0.7848      0.099     -7.892      0.000      -0.980      -0.590
# ...

# %%
modelo2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                SARIMAX Results
# ...
# Dep. Variable:                      y   No. Observations:                   56
# Model:               SARIMAX(0, 0, 1)   Log Likelihood                 -14.084
# Date:                Sun, 04 Aug 2024   AIC                             32.167
# Time:                        11:24:14   BIC                             36.218
# Sample:                    06-30-2009   HQIC                            33.738
#                          - 03-31-2023
# Covariance Type:                  opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ma.L1         -0.7938      0.086     -9.241      0.000      -0.962      -0.625
# sigma2         0.0951      0.009     11.184      0.000       0.078       0.112
# ...
# Ljung-Box (L1) (Q):                   0.04   Jarque-Bera (JB):               319.48
# ...

# %%
modelo3.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                                 y   No. Observations:                   56
# Model:             SARIMAX(0, 0, 1)x(1, 0, 1, 4)   Log Likelihood                 -10.377
# Date:                           Sun, 04 Aug 2024   AIC                             30.754
# Time:                                   11:24:14   BIC                             40.881
# Sample:                               06-30-2009   HQIC                            34.680
#                                     - 03-31-2023
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept   3.239e-05      0.003      0.012      0.990      -0.005       0.005
# ma.L1         -0.7848      0.099     -7.892      0.000      -0.980      -0.590
# ...

# %%
modelo4.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ...
# Dep. Variable:                                 y   No. Observations:                   56
# Model:             SARIMAX(3, 0, 0)x(1, 0, 0, 4)   Log Likelihood                 -10.947
# Date:                           Sun, 04 Aug 2024   AIC                             31.894
# Time:                                   11:24:14   BIC                             42.021
# Sample:                               06-30-2009   HQIC                            35.820
#                                     - 03-31-2023
# Covariance Type:                             opg
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0.7293      0.107     -6.836      0.000      -0.938      -0.520
# ar.L2         -0.7566      0.135     -5.612      0.000      -1.021      -0.492
# ...

# %%
modelo1.plot_diagnostics(figsize=(10,8));

# %% [markdown]
# ## Predicción

# %%
pred0 = modelo0.forecast(4)
pred1 = modelo1.predict(4)
pred2 = modelo2.predict(4)

# %%
test['Modelo 0'] = pred0
test['Modelo 1'] = pred1
test['Modelo 2'] = pred2
# Out:
# C:\Users\josea\AppData\Local\Temp\ipykernel_8788\66793677.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Modelo 0'] = pred0
# C:\Users\josea\AppData\Local\Temp\ipykernel_8788\66793677.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Modelo 1'] = pred1
# C:\Users\josea\AppData\Local\Temp\ipykernel_8788\66793677.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
test
# Out:
#                  EPS  Modelo 0  Modelo 1  Modelo 2
# Fecha
# 2023-06-30  0.000000 -0.121652 -0.100359   0.02756
# 2023-09-30  0.289505  0.263493  0.249701   0.00000
# 2023-12-31 -0.267844  0.029913  0.028770   0.00000
# 2024-03-31  0.082238 -0.130430 -0.119066   0.00000

# %%
fig, ax = plt.subplots()
ax.plot(eps_tasa.index,eps_tasa['EPS'])
ax.plot(test['EPS'], 'b-', label='Observado')
ax.plot(test['Modelo 0'], 'k--', label='Modelo 0')
ax.plot(test['Modelo 1'], 'r--', label='Modelo 1')
ax.plot(test['Modelo 2'], 'g--', label='Modelo 2')
ax.legend(loc=2);

# %%
def rolling_forecast(endog, train_len, horizon, order, seasonal_order = (0,0,0,0), disp = False, with_intercept = True):
    data = np.array(endog)
    total_len = train_len + horizon
    pred_SARIMA = []
    trend = "n"
    if with_intercept:
        trend = "c"
    for i in range(train_len, total_len, 1):
        if disp:
            print(len(data[:i]))
        model = SARIMAX(data[:i],
                        order=order,
                        seasonal_order=seasonal_order, 
                        simple_differencing=False,
                       trend = trend)
        res = model.fit(disp=False)
        predictions = res.forecast(1)
        pred_SARIMA.extend(predictions)
        if(i >= len(endog)):
            if disp:
                print("Ingreso nuevo dato")
            data = np.append(data,np.array(predictions))
    return pred_SARIMA

# %%
predict0 = rolling_forecast(eps_tasa, len(train), 10, (0,0,1),(1,0,1,4), with_intercept = False)
predict0
# Out:
# [-0.12165213870450496,
#  0.16791557948286023,
#  -0.06191363242903166,
#  0.02850159211744624,
#  -0.17202144858323118,
#  0.26391832215265226,
#  0.013377502345223415,
#  -0.11848004000618388,
#  -0.13424302245967842,
#  0.26740050002872057]

# %%
predict1 = rolling_forecast(eps_tasa, len(train), 10, (0,0,1), (1,0,1,4), with_intercept = True)
predict1
# Out:
# [-0.10035933074913903,
#  0.17253178402445607,
#  -0.060038450472362254,
#  0.039036441206567615,
#  -0.1590838225375282,
#  0.26027516956333896,
#  0.008642947289711614,
#  -0.10466597336662355,
#  -0.12861961676115444,
#  0.2569701637499257]

# %%
predict2 = rolling_forecast(eps_tasa, len(train), 10, (0,0,1), with_intercept = False)
predict2
# Out:
# [0.02756018485760973,
#  0.02170668282869718,
#  -0.2112379125133846,
#  0.04431052649021496,
#  -0.02994226274278648,
#  -3.7696079721048725e-05,
#  -2.902962461336951e-05,
#  -2.236645145444762e-05,
#  -1.7230643545853708e-05,
#  -1.3260029049800544e-05]
